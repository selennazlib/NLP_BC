# %%
import spacy 
import spacy.cli

# %%
spacy.cli.download("en_core_web_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
nlp = spacy.load('en_core_web_lg')

# %%
nlp(u'lion').vector
# Out:
# array([  1.2746  ,   0.46242 ,  -1.1829  ,  -5.2661  ,  -2.7128  ,
#          1.8521  ,  -0.94273 ,   2.1865  ,   6.503   ,   0.6704  ,
#          1.5361  ,   2.5992  ,  -0.36233 ,   4.3965  ,  -6.5644  ,
#          1.6141  ,  -1.2897  ,   2.1184  ,  -0.63654 ,  -3.4572  ,
#         -4.3771  ,   4.2074  ,  -3.6411  ,  -0.97214 ,   1.3253  ,
#         -2.3125  ,  -3.6531  ,  -2.8398  ,   2.7913  ,  -1.53    ,
#         -2.9984  ,  -2.6357  ,   0.50615 ,  -2.6925  ,   4.3401  ,
#         -5.6017  ,   0.045691,   4.3832  ,  -0.19535 ,  -1.0751  ,
#          0.32172 ,   2.4395  ,   4.6638  ,   3.4471  ,  -3.3847  ,
#         -1.8238  ,   0.70212 ,   0.58557 ,   5.0032  ,  -3.1072  ,
#          1.2364  ,   7.4595  ,   0.057368,   1.0111  ,  -1.0827  ,
#          0.69113 ,   2.8009  ,  -3.4383  ,  -1.0599  ,  -2.2627  ,
#         -5.149   ,  -5.0636  ,   3.1405  ,   1.0793  ,  -0.72892 ,
#         -3.9939  ,  -0.69551 ,  -0.55767 ,   3.2555  ,  -2.9449  ,
# ...

# %%
nlp(u'.').vector
# Out:
# array([-0.076454, -4.6896  , -4.0431  , -3.4333  , 11.758   ,  3.7212  ,
#        -0.98133 ,  2.7902  ,  0.43608 , -2.4425  ,  6.9311  ,  2.7647  ,
#        -1.7035  ,  6.3123  ,  2.6301  ,  1.1136  , -3.3689  , -5.4062  ,
#        -3.6021  , -9.8479  ,  4.6016  , -0.50542 ,  0.66145 , -3.552   ,
#        -4.3909  , -2.3702  , -1.8251  , -4.8768  ,  2.7245  ,  5.3177  ,
#        -0.50146 , -7.2556  , -4.6895  , -5.4604  , -5.6257  ,  1.6121  ,
#        -0.8789  ,  1.6936  ,  1.9308  ,  6.7769  ,  3.6739  ,  0.28693 ,
#        -0.22849 , -4.0779  , -4.7086  ,  2.0722  , -2.3405  , -1.6884  ,
#        -1.9876  , -2.2207  , -2.6514  ,  3.3686  ,  0.12579 , -5.8689  ,
#         4.6715  ,  1.1999  , -4.3008  ,  2.1239  ,  0.029298,  3.0072  ,
#        -2.4435  , -3.9103  ,  1.0187  , -2.0263  ,  5.0496  ,  0.66619 ,
#        -3.978   , -4.0066  , -1.8538  ,  0.65539 , -2.1525  , -9.2576  ,
#        -2.6783  , -1.4023  ,  4.0334  , -2.3129  , -5.1051  , -0.91791 ,
# ...

# %%
tokens = nlp(u'cloud rain sun thunder')

for token1 in tokens:
  for token2 in tokens:
    print(token1.text, token2.text, token1.similarity(token2)) # cosine similarity
# Out:
# cloud cloud 1.0
# cloud rain 0.3453340530395508
# cloud sun 0.30807122588157654
# cloud thunder 0.32086485624313354
# rain cloud 0.3453340530395508
# rain rain 1.0
# rain sun 0.5689597129821777
# rain thunder 0.5538451075553894
# sun cloud 0.30807122588157654
# sun rain 0.5689597129821777
# sun sun 1.0
# sun thunder 0.37697848677635193
# thunder cloud 0.32086485624313354
# thunder rain 0.5538451075553894
# thunder sun 0.37697848677635193
# thunder thunder 1.0

# %%
tokens = nlp(u'like love pavpav') # I made up the last one
for token1 in tokens:
  print(token1.text, token1.has_vector, token1.vector_norm, token1.is_oov)
# Out:
# like True 50.609623 False
# love True 58.563564 False
# pavpav False 0.0 True
